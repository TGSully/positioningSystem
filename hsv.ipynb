# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# %matplotlib inline

image = cv2.imread("./corner.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]
plt.imshow(r, cmap="gray")

# %%
hsvimage = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
h = hsvimage[:,:,0]
plt.imshow(h, cmap="gray")

# %%
hsvimage[1, 1079, :]
# Out:
# array([140,   3, 221], dtype=uint8)

# %%
uppperHue = np.array([75, 0, 0])
lowerHue =  np.array([90, 255, 255])

# %%
mask = cv2.inRange(hsvimage, uppperHue, lowerHue)
plt.imshow(mask)

# %%
mask_2 = cv2.inRange(h, 120, 125)
plt.imshow(mask, cmap='gray')
